# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

current_model = "gemini-2.5-flash-lite"
current_provider = "google_genai"

model = init_chat_model(
    model=current_model, 
    model_provider=current_provider
)

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content="That's a fun question! The Moon doesn't have a capital city in the way Earth does. It's a celestial body, not a country or political entity with a government and defined settlements.\n\nSo, the answer is: **The Moon has no capital.**", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e26c9-e8d0-72e0-bcdf-a484e0ff0bff-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 56, 'total_tokens': 66, 'input_token_details': {'cache_read': 0}})

# %%
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city in the way Earth does. It's a celestial body, not a country or political entity with a government and defined settlements.
#
# So, the answer is: **The Moon has no capital.**

# %%
from pprint import pprint

pprint(response.response_metadata)

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model=current_model, 
    model_provider=current_provider,
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
ANTHROPIC_model = init_chat_model(model="claude-sonnet-4-5")
response = ANTHROPIC_model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
GOOGLE_model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
response = GOOGLE_model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)

# %%
print(response['messages'][-1].content)

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
